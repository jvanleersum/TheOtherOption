# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../TheOtherOption/data/all_products_ah_nutr_allergies.csv")

# %%
df.head()
# Out:
#    allergy        id brand                                      category  \
# 0  no_info   wi54074    AH    Aardappel, groente, fruit/Komkommer (vers)
# 1  no_info  wi197393    AH             Aardappel, groente, fruit/Bananen
# 2  no_info    wi4164    AH    Aardappel, groente, fruit/Courgette (vers)
# 3  no_info   wi41194    AH  Aardappel, groente, fruit/Paprika mix (vers)
# 4  no_info    wi4177    AH     Aardappel, groente, fruit/Broccoli (vers)
#
#       description                                           features  \
# 0    AH Komkommer  ['vegetarian', 'free_from_gluten', 'free_from_...
# 1      AH Bananen  ['ah_vegan', 'free_from_milk', 'free_from_glut...
# 2    AH Courgette  ['vegetarian', 'free_from_milk', 'free_from_gl...
# 3  AH Paprika mix  ['ah_vegan', 'free_from_gluten', 'free_from_mi...
# 4     AH Broccoli                                                NaN
#
#                                            image_url ingredients  \
# 0  https://static.ah.nl/static/product/AHI_434d50...     no info
# 1  https://static.ah.nl/static/product/AHI_435452...     no info
# 2  https://static.ah.nl/static/product/AHI_434d50...     no info
# 3  https://static.ah.nl/static/product/AHI_435452...     no info
# 4  https://static.ah.nl/static/product/AHI_435452...     no info
#
#                                            nutrition  \
# 0                                            no info
# 1  {'Eiwitten': '1 g', 'Energie': '385 kJ (91 kca...
# 2                                            no info
# 3  {'Eiwitten': '0.8 g', 'Energie': '100 kJ (24 k...
# 4                                            no info
#
#                                              summary  ... sulfieten haver  \
# 0  Komkommer heeft een frisse, knapperige, neutra...  ...       NaN   NaN
# 1  Bananen met een zachte en zoete smaak. Lekker ...  ...       NaN   NaN
# 2  De courgette heeft een frisse, zachte, redelij...  ...       NaN   NaN
# 3                                                NaN  ...       NaN   NaN
# 4  Broccoli heeft een knapperige, frisse iets pit...  ...       NaN   NaN
#
#   spelt gerst pinda's (aardnoten) cashewnoot pecannoot hazelnoot  \
# 0   NaN   NaN                 NaN        NaN       NaN       NaN
# 1   NaN   NaN                 NaN        NaN       NaN       NaN
# 2   NaN   NaN                 NaN        NaN       NaN       NaN
# 3   NaN   NaN                 NaN        NaN       NaN       NaN
# 4   NaN   NaN                 NaN        NaN       NaN       NaN
#
#   macadamianoot paranoot
# 0           NaN      NaN
# 1           NaN      NaN
# 2           NaN      NaN
# 3           NaN      NaN
# 4           NaN      NaN
#
# [5 rows x 145 columns]

# %%
df["features"] = df["features"].fillna('no_info')

# %%
all_features = []
for features in df["features"]:
    if features != "no_info":
        for f in eval(features):
            all_features.append(f)
all_features = set(all_features)

# %%
all_features
# Out:
# {'ah_vegan',
#  'ah_vegetarian',
#  'beter_leven_1_ster',
#  'bio_label_german',
#  'biological',
#  'certified_b_corporation',
#  'dah_kip',
#  'eko',
#  'eu_organic_farming',
#  'european_v_label_vegan',
#  'european_v_label_vegetarian',
#  'fair_trade_mark',
#  'forest_stewardship_council_label',
#  'forest_stewardship_council_mix',
#  'free_from_gluten',
#  'free_from_lactose',
#  'free_from_milk',
#  'free_from_milk_protein',
#  'green_dot',
#  'marine_stewardship_council_label',
#  'nutriscore_a',
#  'on_the_way_to_planetproof',
#  'rainforest_alliance',
#  'recyclable_general_claim',
#  'scs_sustainably_grown',
#  'society_plastics_industry',
#  'vegan',
#  'vegan_society_vegan_logo',
#  'vegetarian'}
