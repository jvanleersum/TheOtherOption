# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
for filename in os.listdir("../TheOtherOption/data/"):
    if filename.endswith(".csv"):
        print(filename)
# Out:
# unparsed_urls.csv
# zuivel-plantaardig-en-eieren.csv
# salades-pizza-maaltijden.csv
# soepen-sauzen-kruiden-olie.csv
# bier-sterke-drank-aperitieven.csv
# vlees-kip-vis-vega.csv
# aardappel-groente-fruit.csv
# bewuste-voeding.csv
# ontbijtgranen-broodbeleg-tussendoor.csv
# pasta-rijst-en-wereldkeuken.csv
# kaas-vleeswaren-tapas.csv
# diepvries.csv
# frisdrank-sappen-koffie-thee.csv
# snoep-koek-chips-en-chocolade.csv
# bakkerij-en-banket.csv
# wijn-en-bubbels.csv

# %%
files = ["aardappel-groente-fruit.csv",
         "zuivel-plantaardig-en-eieren.csv",
         "salades-pizza-maaltijden.csv",
         'soepen-sauzen-kruiden-olie.csv',
         "bier-sterke-drank-aperitieven.csv",
         "vlees-kip-vis-vega.csv",
         "bewuste-voeding.csv", 
         "ontbijtgranen-broodbeleg-tussendoor.csv", 
         "pasta-rijst-en-wereldkeuken.csv",
         "kaas-vleeswaren-tapas.csv",
         "diepvries.csv",
         "frisdrank-sappen-koffie-thee.csv",
         "snoep-koek-chips-en-chocolade.csv",
         "bakkerij-en-banket.csv",
         "wijn-en-bubbels.csv"]

# %%
total_df = pd.read_csv(f"../TheOtherOption/data/{files[0]}")
for file in files[1:]:
    file_df = pd.read_csv(f"../TheOtherOption/data/{file}")
    total_df.append(file_df, ignore_index=True)

# %%
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 1003
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   allergy      1000 non-null   object
#  1   id           1000 non-null   object
#  2   brand        998 non-null    object
#  3   category     1000 non-null   object
#  4   description  1000 non-null   object
#  5   features     830 non-null    object
#  6   image_url    999 non-null    object
#  7   ingredients  1000 non-null   object
#  8   nutrition    1000 non-null   object
#  9   summary      907 non-null    object
#  10  unit_size    1000 non-null   object
#  11  url          1000 non-null   object
# dtypes: object(12)
# memory usage: 101.6+ KB

# %%
total_df = total_df.drop_duplicates()

# %%
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 1003
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   allergy      1000 non-null   object
#  1   id           1000 non-null   object
#  2   brand        998 non-null    object
#  3   category     1000 non-null   object
#  4   description  1000 non-null   object
#  5   features     830 non-null    object
#  6   image_url    999 non-null    object
#  7   ingredients  1000 non-null   object
#  8   nutrition    1000 non-null   object
#  9   summary      907 non-null    object
#  10  unit_size    1000 non-null   object
#  11  url          1000 non-null   object
# dtypes: object(12)
# memory usage: 101.6+ KB

# %%
total_df.head()
# Out:
#    allergy        id brand                                      category  \
# 0  no_info   wi54074    AH    Aardappel, groente, fruit/Komkommer (vers)
# 1  no_info  wi197393    AH             Aardappel, groente, fruit/Bananen
# 2  no_info    wi4164    AH    Aardappel, groente, fruit/Courgette (vers)
# 3  no_info   wi41194    AH  Aardappel, groente, fruit/Paprika mix (vers)
# 4  no_info    wi4177    AH     Aardappel, groente, fruit/Broccoli (vers)
#
#       description                                           features  \
# 0    AH Komkommer  ['vegetarian', 'free_from_gluten', 'free_from_...
# 1      AH Bananen  ['ah_vegan', 'free_from_milk', 'free_from_glut...
# 2    AH Courgette  ['vegetarian', 'free_from_milk', 'free_from_gl...
# 3  AH Paprika mix  ['ah_vegan', 'free_from_gluten', 'free_from_mi...
# 4     AH Broccoli                                                NaN
#
#                                            image_url ingredients  \
# 0  https://static.ah.nl/static/product/AHI_434d50...     no info
# 1  https://static.ah.nl/static/product/AHI_435452...     no info
# 2  https://static.ah.nl/static/product/AHI_434d50...     no info
# 3  https://static.ah.nl/static/product/AHI_435452...     no info
# 4  https://static.ah.nl/static/product/AHI_435452...     no info
#
#                                            nutrition  \
# 0                                            no info
# 1  {'Eiwitten': '1 g', 'Energie': '385 kJ (91 kca...
# 2                                            no info
# 3  {'Eiwitten': '0.8 g', 'Energie': '100 kJ (24 k...
# 4                                            no info
#
#                                              summary unit_size  \
# 0  Komkommer heeft een frisse, knapperige, neutra...  per stuk
# 1  Bananen met een zachte en zoete smaak. Lekker ...      Tros
# 2  De courgette heeft een frisse, zachte, redelij...  per stuk
# 3                                                NaN   3 stuks
# 4  Broccoli heeft een knapperige, frisse iets pit...     500 g
#
#                                                  url
# 0  https://www.ah.nl/producten/product/wi54074/ah...
# 1  https://www.ah.nl/producten/product/wi197393/a...
# 2  https://www.ah.nl/producten/product/wi4164/ah-...
# 3  https://www.ah.nl/producten/product/wi41194/ah...
# 4  https://www.ah.nl/producten/product/wi4177/ah-...

# %%
total_df.to_csv("../TheOtherOption/data/all_products_ah.csv")

# %%
total_df
# Out:
#       allergy        id             brand  \
# 0     no_info   wi54074                AH
# 1     no_info  wi197393                AH
# 2     no_info    wi4164                AH
# 3     no_info   wi41194                AH
# 4     no_info    wi4177                AH
# ...       ...       ...               ...
# 999   no_info  wi478488         Bonduelle
# 1000  no_info  wi494839          AH Culii
# 1001  no_info  wi493472  Lucien Georgelin
# 1002  no_info  wi493473  Lucien Georgelin
# 1003  no_info    wi4090                AH
#
#                                                category  \
# 0            Aardappel, groente, fruit/Komkommer (vers)
# 1                     Aardappel, groente, fruit/Bananen
# 2            Aardappel, groente, fruit/Courgette (vers)
# 3          Aardappel, groente, fruit/Paprika mix (vers)
# 4             Aardappel, groente, fruit/Broccoli (vers)
# ...                                                 ...
# 999   Aardappel, groente, fruit/Groentepasta, rijst ...
# 1000           Aardappel, groente, fruit/Witte asperges
# 1001  Ontbijtgranen, broodbeleg, tussendoor/Fruit sp...
# 1002  Ontbijtgranen, broodbeleg, tussendoor/Fruit sp...
# 1003       Aardappel, groente, fruit/Verse vleestomaten
#
#                                        description  \
# 0                                     AH Komkommer
# 1                                       AH Bananen
# 2                                     AH Courgette
# 3                                   AH Paprika mix
# 4                                      AH Broccoli
# ...                                            ...
# 999   Bonduelle 100% erwten & courgette rijst vorm
# 1000                   AH Culii Asperges bearnaise
# 1001      Lucien Georgelin Abrikoos vruchtenspread
# 1002       Lucien Georgelin Aardbei vruchtenspread
# 1003                               AH Vleestomaten
#
#                                                features  \
# 0     ['vegetarian', 'free_from_gluten', 'free_from_...
# 1     ['ah_vegan', 'free_from_milk', 'free_from_glut...
# 2     ['vegetarian', 'free_from_milk', 'free_from_gl...
# 3     ['ah_vegan', 'free_from_gluten', 'free_from_mi...
# 4                                                   NaN
# ...                                                 ...
# 999           ['recyclable_general_claim', 'green_dot']
# 1000                                                NaN
# 1001                       ['recyclable_general_claim']
# 1002                       ['recyclable_general_claim']
# 1003  ['vegetarian', 'free_from_gluten', 'free_from_...
#
#                                               image_url  \
# 0     https://static.ah.nl/static/product/AHI_434d50...
# 1     https://static.ah.nl/static/product/AHI_435452...
# 2     https://static.ah.nl/static/product/AHI_434d50...
# 3     https://static.ah.nl/static/product/AHI_435452...
# 4     https://static.ah.nl/static/product/AHI_435452...
# ...                                                 ...
# 999   https://static.ah.nl/static/product/AHI_435452...
# 1000  https://static.ah.nl/static/product/AHI_435452...
# 1001  https://static.ah.nl/static/product/AHI_435452...
# 1002  https://static.ah.nl/static/product/AHI_435452...
# 1003  https://static.ah.nl/static/product/AHI_434d50...
#
#                                             ingredients  \
# 0                                               no info
# 1                                               no info
# 2                                               no info
# 3                                               no info
# 4                                               no info
# ...                                                 ...
# 999   ['Spliterwtenbloem 95%', 'courgette gedroogd 5...
# 1000                                            no info
# 1001  ['Abrikozen 45% (herkomst: Frankrijk)', 'suike...
# 1002  ['Aardbeien 45% (EU / niet-EU-oorsprong)', 'su...
# 1003                                            no info
#
#                                               nutrition  \
# 0                                               no info
# 1     {'Eiwitten': '1 g', 'Energie': '385 kJ (91 kca...
# 2                                               no info
# 3     {'Eiwitten': '0.8 g', 'Energie': '100 kJ (24 k...
# 4                                               no info
# ...                                                 ...
# 999   {'Eiwitten': '21.5 g', 'Energie': '1439 kJ (34...
# 1000                                            no info
# 1001  {'Eiwitten': '< 0.5 g', 'Energie': '768 kJ (18...
# 1002  {'Eiwitten': '< 0.5 g', 'Energie': '785 kJ (18...
# 1003                                            no info
#
#                                                 summary      unit_size  \
# 0     Komkommer heeft een frisse, knapperige, neutra...       per stuk
# 1     Bananen met een zachte en zoete smaak. Lekker ...           Tros
# 2     De courgette heeft een frisse, zachte, redelij...       per stuk
# 3                                                   NaN        3 stuks
# 4     Broccoli heeft een knapperige, frisse iets pit...          500 g
# ...                                                 ...            ...
# 999   Rijst, gemaakt van groente! Groenterijst van 1...          300 g
# 1000                                                NaN     2 personen
# 1001                                                NaN          320 g
# 1002                                                NaN          320 g
# 1003  Let op: dit product wordt in de winkel gewogen...  los per 500 g
#
#                                                     url
# 0     https://www.ah.nl/producten/product/wi54074/ah...
# 1     https://www.ah.nl/producten/product/wi197393/a...
# 2     https://www.ah.nl/producten/product/wi4164/ah-...
# 3     https://www.ah.nl/producten/product/wi41194/ah...
# 4     https://www.ah.nl/producten/product/wi4177/ah-...
# ...                                                 ...
# 999   https://www.ah.nl/producten/product/wi478488/b...
# 1000  https://www.ah.nl/producten/product/wi494839/a...
# 1001  https://www.ah.nl/producten/product/wi493472/l...
# 1002  https://www.ah.nl/producten/product/wi493473/l...
# 1003  https://www.ah.nl/producten/product/wi4090/ah-...
#
# [1000 rows x 12 columns]
