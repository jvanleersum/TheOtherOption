# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
for filename in os.listdir("../TheOtherOption/data/"):
    if filename.endswith(".csv"):
        print(filename)
# Out:
# unparsed_urls.csv
# all_products_ah_nutr.csv
# zuivel-plantaardig-en-eieren.csv
# salades-pizza-maaltijden.csv
# features_list.csv
# soepen-sauzen-kruiden-olie.csv
# bier-sterke-drank-aperitieven.csv
# all_products_ah_nutr_allergies.csv
# vlees-kip-vis-vega.csv
# aardappel-groente-fruit.csv
# nutrients_list.csv
# bewuste-voeding.csv
# ontbijtgranen-broodbeleg-tussendoor.csv
# pasta-rijst-en-wereldkeuken.csv
# kaas-vleeswaren-tapas.csv
# all_products_ah.csv
# diepvries.csv
# allergies_list.csv
# frisdrank-sappen-koffie-thee.csv
# snoep-koek-chips-en-chocolade.csv
# all_products_ah_nutr_allergies_features.csv
# bakkerij-en-banket.csv
# wijn-en-bubbels.csv

# %%
files = ["aardappel-groente-fruit.csv",
         "zuivel-plantaardig-en-eieren.csv",
         "salades-pizza-maaltijden.csv",
         'soepen-sauzen-kruiden-olie.csv',
         "bier-sterke-drank-aperitieven.csv",
         "vlees-kip-vis-vega.csv",
         "bewuste-voeding.csv", 
         "ontbijtgranen-broodbeleg-tussendoor.csv", 
         "pasta-rijst-en-wereldkeuken.csv",
         "kaas-vleeswaren-tapas.csv",
         "diepvries.csv",
         "frisdrank-sappen-koffie-thee.csv",
         "snoep-koek-chips-en-chocolade.csv",
         "bakkerij-en-banket.csv",
         "wijn-en-bubbels.csv"]

# %%
total_df = pd.read_csv(f"../TheOtherOption/data/{files[0]}")
for file in files[1:]:
    file_df = pd.read_csv(f"../TheOtherOption/data/{file}")
    total_df = total_df.append(file_df, ignore_index=True)

# %%
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13911 entries, 0 to 13910
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   allergy      13911 non-null  object
#  1   id           13911 non-null  object
#  2   brand        13860 non-null  object
#  3   category     13911 non-null  object
#  4   description  13911 non-null  object
#  5   features     9843 non-null   object
#  6   image_url    13851 non-null  object
#  7   ingredients  13911 non-null  object
#  8   nutrition    13911 non-null  object
#  9   summary      12679 non-null  object
#  10  unit_size    13908 non-null  object
#  11  url          13911 non-null  object
# dtypes: object(12)
# memory usage: 1.3+ MB

# %%
total_df = total_df.drop_duplicates()

# %%
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10883 entries, 0 to 13909
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   allergy      10883 non-null  object
#  1   id           10883 non-null  object
#  2   brand        10833 non-null  object
#  3   category     10883 non-null  object
#  4   description  10883 non-null  object
#  5   features     7652 non-null   object
#  6   image_url    10826 non-null  object
#  7   ingredients  10883 non-null  object
#  8   nutrition    10883 non-null  object
#  9   summary      9855 non-null   object
#  10  unit_size    10880 non-null  object
#  11  url          10883 non-null  object
# dtypes: object(12)
# memory usage: 1.1+ MB

# %%
total_df.head()
# Out:
#    allergy        id brand                                      category  \
# 0  no_info   wi54074    AH    Aardappel, groente, fruit/Komkommer (vers)
# 1  no_info  wi197393    AH             Aardappel, groente, fruit/Bananen
# 2  no_info    wi4164    AH    Aardappel, groente, fruit/Courgette (vers)
# 3  no_info   wi41194    AH  Aardappel, groente, fruit/Paprika mix (vers)
# 4  no_info    wi4177    AH     Aardappel, groente, fruit/Broccoli (vers)
#
#       description                                           features  \
# 0    AH Komkommer  ['vegetarian', 'free_from_gluten', 'free_from_...
# 1      AH Bananen  ['ah_vegan', 'free_from_milk', 'free_from_glut...
# 2    AH Courgette  ['vegetarian', 'free_from_milk', 'free_from_gl...
# 3  AH Paprika mix  ['ah_vegan', 'free_from_gluten', 'free_from_mi...
# 4     AH Broccoli                                                NaN
#
#                                            image_url ingredients  \
# ...

# %%
total_df.to_csv("../TheOtherOption/data/all_products_ah.csv")

# %%
total_df
# Out:
#              allergy        id                brand  \
# 0            no_info   wi54074                   AH
# 1            no_info  wi197393                   AH
# 2            no_info    wi4164                   AH
# 3            no_info   wi41194                   AH
# 4            no_info    wi4177                   AH
# ...              ...       ...                  ...
# 13905  ['sulfieten']  wi160480           Neil Ellis
# 13906  ['sulfieten']  wi160524              Pommery
# 13907  ['sulfieten']  wi161982  Domaine grand Tinel
# 13908        no_info  wi171669       Maitre de Chai
# 13909        no_info  wi178255                 Masi
#
#                                                category  \
# 0            Aardappel, groente, fruit/Komkommer (vers)
# 1                     Aardappel, groente, fruit/Bananen
# 2            Aardappel, groente, fruit/Courgette (vers)
# 3          Aardappel, groente, fruit/Paprika mix (vers)
# ...
